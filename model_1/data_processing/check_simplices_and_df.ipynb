# %% [markdown]
# Testing the processed data

# %%
# Load the libraries
import numpy as np
import pandas as pd

# %%
df_path = "/home/h6x/git_projects/ornl-gnn-experiment/model_1/data/processed/GNN_simplices_data_2018/processed_filtered_df.csv"
simplices_pkl_path = "/home/h6x/git_projects/ornl-gnn-experiment/model_1/data/processed/GNN_simplices_data_2018/simplices.pkl"

# %%
filtered_df = pd.read_csv(df_path)

# %%
filtered_df.shape
# Out:
# (95, 4)

# %%
filtered_df.head()
# Out:
#     FIPS  NOD_2018                                           geometry  \
# 0  47113  0.000000  POLYGON ((-89.07884699999994 35.43206700000007...
# 1  47075  0.004566  POLYGON ((-89.50140099999999 35.58183600000007...
# 2  47069  0.027397  POLYGON ((-89.19767199999995 35.01182200000005...
# 3  47045  0.031963  POLYGON ((-89.73309499999993 36.00060800000006...
# 4  47095  0.034247  POLYGON ((-89.70532799999995 36.23989800000004...
#
#    sortedID
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4

# %%
# load the simplices
import pickle

with open(simplices_pkl_path, 'rb') as f:
    simplices = pickle.load(f)

# %%
simplices
# Out:
# [[0],
#  [1],
#  [0, 1],
#  [2],
#  [0, 2],
#  [1, 2],
#  [0, 1, 2],
#  [3],
#  [4],
#  [3, 4],
#  [5],
#  [1, 5],
#  [2, 5],
#  [1, 2, 5],
#  [6],
#  [0, 6],
#  [1, 6],
#  [0, 1, 6],
#  [3, 6],
#  [7],
#  [3, 7],
#  [4, 7],
#  [3, 4, 7],
#  [8],
#  [0, 8],
#  [2, 8],
#  [0, 2, 8],
#  [9],
#  [10],
#  [5, 10],
#  [11],
#  [1, 11],
#  [3, 11],
#  [6, 11],
#  [1, 6, 11],
#  [3, 6, 11],
#  [12],
#  [0, 12],
#  [13],
#  [14],
#  [15],
#  [13, 15],
#  [16],
#  [17],
#  [18],
#  [7, 18],
#  [12, 18],
#  [19],
#  [0, 19],
#  [3, 19],
#  [6, 19],
#  [0, 6, 19],
#  [3, 6, 19],
#  [7, 19],
#  [3, 7, 19],
#  [12, 19],
#  [0, 12, 19],
#  [18, 19],
#  [12, 18, 19],
#  [7, 18, 19],
#  [20],
#  [21],
#  [2, 21],
#  [8, 21],
#  [2, 8, 21],
#  [22],
#  [14, 22],
#  [23],
#  [24],
#  [14, 24],
#  [25],
#  [26],
#  [20, 26],
#  [27],
#  [13, 27],
#  [20, 27],
#  [26, 27],
#  [20, 26, 27],
#  [28],
#  [20, 28],
#  [26, 28],
#  [20, 26, 28],
#  [29],
#  [30],
#  [17, 30],
#  [31],
#  [25, 31],
# ...
